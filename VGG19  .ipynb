1.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1003/0.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/1003/5.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1003/3.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1003/2.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/103/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/103/2.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/103/3.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/103/1.jpg (deflated 16%)
#   adding: content/drive/MyDrive/gene_name/103/0.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1054/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/1054/1.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1054/0.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1081/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/1081/0.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/1081/1.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/104/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/104/7.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/104/3.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/104/8.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/104/5.jpg (deflated 5%)
#   adding: content/drive/MyDrive/gene_name/104/9.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/104/6.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/104/4.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/104/0.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/104/2.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/104/1.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/108/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/108/2.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/108/1.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/108/8.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/108/6.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/108/7.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/108/3.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/108/0.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/108/5.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/108/4.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/102/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/102/2.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/102/0.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/102/1.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1076/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/1076/1.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1076/0.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/105/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/105/2.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/105/0.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/105/5.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/105/3.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/105/4.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/105/1.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/1072/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/1072/3.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/1072/5.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1072/0.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1072/1.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/1072/2.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1072/6.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/1072/4.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/0/11.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/10.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/68.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/13.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/53.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/6.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/99.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/104.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/17.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/93.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/19.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/73.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/44.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/74.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/46.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/18.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/95.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/0/4.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/1.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/29.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/51.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/100.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/0/32.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/52.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/97.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/36.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/106.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/102.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/49.jpg (deflated 16%)
#   adding: content/drive/MyDrive/gene_name/0/35.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/101.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/66.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/67.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/56.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/0/34.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/78.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/9.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/24.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/85.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/25.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/75.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/41.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/27.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/47.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/0/86.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/0/77.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/69.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/50.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/45.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/12.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/48.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/0/30.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/23.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/72.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/59.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/3.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/65.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/54.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/92.jpg (deflated 16%)
#   adding: content/drive/MyDrive/gene_name/0/61.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/8.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/88.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/96.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/31.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/70.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/103.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/16.jpg (deflated 18%)
#   adding: content/drive/MyDrive/gene_name/0/21.jpg (deflated 5%)
#   adding: content/drive/MyDrive/gene_name/0/33.jpg (deflated 5%)
#   adding: content/drive/MyDrive/gene_name/0/28.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/0/7.jpg (deflated 5%)
#   adding: content/drive/MyDrive/gene_name/0/62.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/0/79.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/43.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/105.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/0/42.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/63.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/22.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/76.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/94.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/58.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/82.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/107.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/91.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/0/81.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/20.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/40.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/60.jpg (deflated 10%)
#   adding: content/drive/MyDrive/gene_name/0/71.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/0/39.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/0/2.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/0.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/83.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/14.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/90.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/15.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/0/26.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/98.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/0/87.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/0/89.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/0/84.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/0/38.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/0/55.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/0/37.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/0/80.jpg (deflated 11%)
#   adding: content/drive/MyDrive/gene_name/0/5.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/0/64.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/0/57.jpg (deflated 12%)
#   adding: content/drive/MyDrive/gene_name/10/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/10/1.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/10/0.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/10/2.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/1/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/1/19.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1/4.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/1/23.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/1/16.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/1/12.jpg (deflated 16%)
#   adding: content/drive/MyDrive/gene_name/1/15.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1/10.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1/18.jpg (deflated 13%)
#   adding: content/drive/MyDrive/gene_name/1/2.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/1/22.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/1/13.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1/1.jpg (deflated 18%)
#   adding: content/drive/MyDrive/gene_name/1/14.jpg (deflated 19%)
#   adding: content/drive/MyDrive/gene_name/1/5.jpg (deflated 17%)
#   adding: content/drive/MyDrive/gene_name/1/17.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/1/7.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1/21.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1/20.jpg (deflated 16%)
#   adding: content/drive/MyDrive/gene_name/1/3.jpg (deflated 15%)
#   adding: content/drive/MyDrive/gene_name/1/0.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/1/11.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/1/8.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/1/9.jpg (deflated 18%)
#   adding: content/drive/MyDrive/gene_name/1/6.jpg (deflated 9%)
#   adding: content/drive/MyDrive/gene_name/100/ (stored 0%)
#   adding: content/drive/MyDrive/gene_name/100/0.jpg (deflated 14%)
#   adding: content/drive/MyDrive/gene_name/100/5.jpg (deflated 8%)
#   adding: content/drive/MyDrive/gene_name/100/3.jpg (deflated 6%)
#   adding: content/drive/MyDrive/gene_name/100/2.jpg (deflated 7%)
#   adding: content/drive/MyDrive/gene_name/100/4.jpg (deflated 5%)
#   adding: content/drive/MyDrive/gene_name/100/1.jpg (deflated 14%)

# %%
# !unzip /content/datazip.zip

# %%
# Setting random seeds to enable consistency while testing.
random.seed(5)
np.random.seed(5)
tf.random.set_seed(5)

ROOT = "/content/drive/MyDrive/gene_name"

def read_image(index):
    path = os.path.join(ROOT, index[0], index[1])
    image = cv2.imread(path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image =cv2.resize(image,(128,128))
    return image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3950d97eefd1> in <module>
#       1 # Setting random seeds to enable consistency while testing.
# ----> 2 random.seed(5)
#       3 np.random.seed(5)
#       4 tf.random.set_seed(5)
#       5
#
# NameError: name 'random' is not defined

# %%
def split_dataset(directory, split=0.9):
    folders = os.listdir(directory)
    num_train = int(len(folders)*split)
    
    random.shuffle(folders)
    
    train_list, test_list = {}, {}
    
    # Creating Train-list
    for folder in folders[:num_train]:
        num_files = len(os.listdir(os.path.join(directory, folder)))
        train_list[folder] = num_files
    
    # Creating Test-list
    for folder in folders[num_train:]:
        num_files = len(os.listdir(os.path.join(directory, folder)))
        test_list[folder] = num_files  
    return train_list, test_list

train_list, test_list = split_dataset(ROOT, split=0.9)
print("Length of training list:", len(train_list))
print("Length of testing list :", len(test_list))

# train_list, test list contains the folder names along with the number of files in the folder.
print("\nTest List:", test_list)
# Out:
# Length of training list: 426
# Length of testing list : 48
#
# Test List: {'99': 8, '995': 4, '8': 20, '80': 2, '453': 2, '146': 2, '328': 26, '782': 2, '88': 13, '195': 2, '206': 3, '754': 3, '52': 20, '199': 7, '732': 3, '620': 5, '501': 4, '695': 2, '24': 15, '981': 2, '115': 2, '35': 8, '83': 44, '388': 4, '514': 2, '661': 2, '130': 3, '427': 2, '513': 2, '820': 3, '761': 2, '89': 9, '3': 8, '67': 32, '201': 19, '433': 15, '1076': 2, '966': 2, '374': 2, '280': 2, '230': 2, '139': 9, '260': 2, '19': 2, '541': 6, '237': 2, '655': 3, '318': 12}

# %%
def create_triplets(directory, folder_list, max_files=10):
    triplets = []
    folders = list(folder_list.keys())
    
    for folder in folders:
        path = os.path.join(directory, folder)
        files = list(os.listdir(path))[:max_files]
        num_files = len(files)
        
        for i in range(num_files-1):
            for j in range(i+1, num_files):
                anchor = (folder, f"{i}.jpg")
                positive = (folder, f"{j}.jpg")

                neg_folder = folder
                while neg_folder == folder:
                    neg_folder = random.choice(folders)
                neg_file = random.randint(0, folder_list[neg_folder]-1)
                negative = (neg_folder, f"{neg_file}.jpg")

                triplets.append((anchor, positive, negative))
            
    random.shuffle(triplets)
    return triplets

# %%
train_triplet = create_triplets(ROOT, train_list)
test_triplet  = create_triplets(ROOT, test_list)

print("Number of training triplets:", len(train_triplet))
print("Number of testing triplets :", len(test_triplet))

print("\nExamples of triplets:")
for i in range(5):
    print(train_triplet[i])
# Out:
# Number of training triplets: 4919
# Number of testing triplets : 709
#
# Examples of triplets:
# (('414', '0.jpg'), ('414', '2.jpg'), ('335', '6.jpg'))
# (('14', '3.jpg'), ('14', '7.jpg'), ('555', '4.jpg'))
# (('653', '1.jpg'), ('653', '2.jpg'), ('863', '1.jpg'))
# (('134', '1.jpg'), ('134', '4.jpg'), ('629', '2.jpg'))
# (('446', '3.jpg'), ('446', '4.jpg'), ('974', '1.jpg'))

# %%
def get_batch(triplet_list, batch_size=256, preprocess=True):
    batch_steps = len(triplet_list)//batch_size
    
    for i in range(batch_steps+1):
        anchor   = []
        positive = []
        negative = []
        
        j = i*batch_size
        while j<(i+1)*batch_size and j<len(triplet_list):
            a, p, n = triplet_list[j]
            anchor.append(read_image(a))
            positive.append(read_image(p))
            negative.append(read_image(n))
            j+=1
            
        anchor = np.array(anchor)
        positive = np.array(positive)
        negative = np.array(negative)
        
        if preprocess:
            anchor = preprocess_input(anchor)
            positive = preprocess_input(positive)
            negative = preprocess_input(negative)
        
        yield ([anchor, positive, negative])

# %%
num_plots = 4

f, axes = plt.subplots(num_plots, 3, figsize=(15, 20))

for x in get_batch(train_triplet, batch_size=num_plots, preprocess=False):
    a,p,n = x
    for i in range(num_plots):
        axes[i, 0].imshow(a[i])
        axes[i, 1].imshow(p[i])
        axes[i, 2].imshow(n[i])
        i+=1
    break

# %%
from tensorflow.keras import backend, layers, metrics

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.utils import plot_model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
def get_encoder(input_shape):
    """ Returns the image encoding model """

    pretrained_model = VGG19(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False,
        pooling='avg',
    )
    
    for i in range(len(pretrained_model.layers)-27):
        pretrained_model.layers[i].trainable = False

    encode_model = Sequential([
        pretrained_model,
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dense(256, activation="relu"),
        layers.Lambda(lambda x: tf.math.l2_normalize(x, axis=1))
    ], name="Encode_Model")
    return encode_model

# %%
#@title Default title text
class DistanceLayer(layers.Layer):
    # A layer to compute ‖f(A) - f(P)‖² and ‖f(A) - f(N)‖²
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative):
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        an_distance = tf.reduce_sum(tf.square(anchor - negative), -1)
        return (ap_distance, an_distance)
    

def get_siamese_network(input_shape = (128, 128, 3)):
    encoder = get_encoder(input_shape)
    
    # Input Layers for the images
    anchor_input   = layers.Input(input_shape, name="Anchor_Input")
    positive_input = layers.Input(input_shape, name="Positive_Input")
    negative_input = layers.Input(input_shape, name="Negative_Input")
    
    ## Generate the encodings (feature vectors) for the images
    encoded_a = encoder(anchor_input)
    encoded_p = encoder(positive_input)
    encoded_n = encoder(negative_input)
    
    # A layer to compute ‖f(A) - f(P)‖² and ‖f(A) - f(N)‖²
    distances = DistanceLayer()(
        encoder(anchor_input),
        encoder(positive_input),
        encoder(negative_input)
    )
    
    # Creating the Model
    siamese_network = Model(
        inputs  = [anchor_input, positive_input, negative_input],
        outputs = distances,
        name = "Siamese_Network"
    )
    return siamese_network

siamese_network = get_siamese_network()
siamese_network.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Model: "Siamese_Network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Anchor_Input (InputLayer)      [(None, 128, 128, 3  0           []
#                                 )]
#
#  Positive_Input (InputLayer)    [(None, 128, 128, 3  0           []
#                                 )]
#
#  Negative_Input (InputLayer)    [(None, 128, 128, 3  0           []
#                                 )]
#
#  Encode_Model (Sequential)      (None, 256)          20420416    ['Anchor_Input[0][0]',
#                                                                   'Positive_Input[0][0]',
#                                                                   'Negative_Input[0][0]']
#
#  distance_layer (DistanceLayer)  ((None,),           0           ['Encode_Model[3][0]',
#                                  (None,))                         'Encode_Model[4][0]',
#                                                                   'Encode_Model[5][0]']
#
# ==================================================================================================
# Total params: 20,420,416
# Trainable params: 20,419,392
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
plot_model(siamese_network, show_shapes=True, show_layer_names=True)

# %%
class SiameseModel(Model):
    # Builds a Siamese model based on a base-model
    def __init__(self, siamese_network, margin=1.0):
        super(SiameseModel, self).__init__()
        
        self.margin = margin
        self.siamese_network = siamese_network
        self.loss_tracker = metrics.Mean(name="loss")

    def call(self, inputs):
        return self.siamese_network(inputs)

    def train_step(self, data):
        # GradientTape get the gradients when we compute loss, and uses them to update the weights
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)
            
        gradients = tape.gradient(loss, self.siamese_network.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients, self.siamese_network.trainable_weights))
        
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self._compute_loss(data)
        
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def _compute_loss(self, data):
        # Get the two distances from the network, then compute the triplet loss
        ap_distance, an_distance = self.siamese_network(data)
        loss = tf.maximum(ap_distance - an_distance + self.margin, 0.0)
        return loss

    @property
    def metrics(self):
        # We need to list our metrics so the reset_states() can be called automatically.
        return [self.loss_tracker]

# %%
siamese_model = SiameseModel(siamese_network)

optimizer = Adam(learning_rate=1e-3, epsilon=1e-01)
siamese_model.compile(optimizer=optimizer)

# %%
def test_on_triplets(batch_size = 256):
    pos_scores, neg_scores = [], []

    for data in get_batch(test_triplet, batch_size=batch_size):
        prediction = siamese_model.predict(data)
        pos_scores += list(prediction[0])
        neg_scores += list(prediction[1])
    
    accuracy = np.sum(np.array(pos_scores) < np.array(neg_scores)) / len(pos_scores)
    ap_mean = np.mean(pos_scores)
    an_mean = np.mean(neg_scores)
    ap_stds = np.std(pos_scores)
    an_stds = np.std(neg_scores)
    
    print(f"Accuracy on test = {accuracy:.5f}")
    return (accuracy, ap_mean, an_mean, ap_stds, an_stds)

# %%
save_all = False
epochs = 50
batch_size = 128

max_acc = 0
train_loss = []
test_metrics = []

for epoch in range(1, epochs+1):
    t = time.time()
    
    # Training the model on train data
    epoch_loss = []

    for data in get_batch(train_triplet, batch_size=batch_size):
        loss = siamese_model.train_on_batch(data)
        epoch_loss.append(loss)
    epoch_loss = sum(epoch_loss)/len(epoch_loss)
    train_loss.append(epoch_loss)

    print(f"\nEPOCH: {epoch} \t (Epoch done in {int(time.time()-t)} sec)")
    print(f"Loss on train    = {epoch_loss:.5f}")
    
    # Testing the model on test data
    metric = test_on_triplets(batch_size=batch_size)
    test_metrics.append(metric)
    accuracy = metric[0]
    
    # Saving the model weights
    if save_all or accuracy>=max_acc:
        siamese_model.save_weights("siamese_model")
        max_acc = accuracy

# Saving the model after all epochs run
siamese_model.save_weights("siamese_model-final")

# %%
#plt.plot(train_loss)
acc = []
for x in test_metrics:
  acc.append(x[0])
plt.plot(acc)
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['Train', 'Validation'], loc='upper left')
plt.legend(['Validation'], loc='upper left')
plt.show()

# %%
def plot_metrics(loss, metrics):
    # Extracting individual metrics from metrics
    accuracy = metrics[:, 0]
    ap_mean  = metrics[:, 1]
    an_mean  = metrics[:, 2]
    ap_stds  = metrics[:, 3]
    an_stds  = metrics[:, 4]
    
    plt.figure(figsize=(15,5))
    
    # Plotting the loss over epochs
    plt.subplot(121)
    plt.plot(loss, 'b', label='Loss')
    plt.title('Training loss')
    plt.legend()
    
    # Plotting the accuracy over epochs
    plt.subplot(122)
    plt.plot(accuracy, 'r', label='Accuracy')
    plt.title('Testing Accuracy')
    plt.legend()
    
    plt.figure(figsize=(15,5))
    
    # Comparing the Means over epochs
    plt.subplot(121)
    plt.plot(ap_mean, 'b', label='AP Mean')
    plt.plot(an_mean, 'g', label='AN Mean')
    plt.title('Means Comparision')
    plt.legend()
    
    # Plotting the accuracy
    ap_75quartile = (ap_mean+ap_stds)
    an_75quartile = (an_mean-an_stds)
    plt.subplot(122)
    plt.plot(ap_75quartile, 'b', label='AP (Mean+SD)')
    plt.plot(an_75quartile, 'g', label='AN (Mean-SD)')
    plt.title('75th Quartile Comparision')
    plt.legend()

test_metrics = np.array(test_metrics)
plot_metrics(train_loss, test_metrics)

# %%
def extract_encoder(model):
    encoder = get_encoder((128, 128, 3))
    i=0
    for e_layer in model.layers[0].layers[3].layers:
        layer_weight = e_layer.get_weights()
        encoder.layers[i].set_weights(layer_weight)
        i+=1
    return encoder

encoder = extract_encoder(siamese_model)
encoder.save_weights("encoder")
encoder.summary()
# Out:
# Model: "Encode_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  lambda_1 (Lambda)           (None, 256)               0
#
# =================================================================
# Total params: 15,110,720
# Trainable params: 15,109,696
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
def classify_images(face_list1, face_list2, threshold=1.3):
    # Getting the encodings for the passed faces
    tensor1 = encoder.predict(face_list1)
    tensor2 = encoder.predict(face_list2)
    
    distance = np.sum(np.square(tensor1-tensor2), axis=-1)
    prediction = np.where(distance<=threshold, 0, 1)
    return prediction

# %%
def ModelMetrics(pos_list, neg_list):
    true = np.array([0]*len(pos_list)+[1]*len(neg_list))
    pred = np.append(pos_list, neg_list)
    
    # Compute and print the accuracy
    print(f"\nAccuracy of model: {accuracy_score(true, pred)}\n")
    
    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(true, pred)

    categories  = ['Similar','Different']
    names = ['True Similar','False Similar', 'False Different','True Different']
    percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)


pos_list = np.array([])
neg_list = np.array([])

for data in get_batch(test_triplet, batch_size=256):
    a, p, n = data
    pos_list = np.append(pos_list, classify_images(a, p))
    neg_list = np.append(neg_list, classify_images(a, n))
    break

ModelMetrics(pos_list, neg_list)
# Out:
# 8/8 [==============================] - 1s 54ms/step
# 8/8 [==============================] - 0s 45ms/step
# 8/8 [==============================] - 0s 45ms/step
# 8/8 [==============================] - 0s 46ms/step
#
# Accuracy of model: 0.94140625

# %%
train_anchor = []
train_pos = []
train_neg = []
for x in train_triplet:
  a, p, n = x
  train_anchor.append(read_image(a))
  train_pos.append(read_image(p))
  train_neg.append(read_image(n))

cosine_similarity = metrics.CosineSimilarity()

positive_similarity = cosine_similarity(train_anchor, train_pos)
print("Positive similarity:", positive_similarity.numpy())

negative_similarity = cosine_similarity(train_anchor, train_neg)
print("Negative similarity", negative_similarity.numpy())
# Out:
# Positive similarity: 0.9489007
# Negative similarity 0.94380814

# %%
test_anchor = []
test_pos = []
test_neg = []
for x in test_triplet:
  a, p, n = x
  test_anchor.append(read_image(a))
  test_pos.append(read_image(p))
  test_neg.append(read_image(n))

cosine_similarity = metrics.CosineSimilarity()

positive_similarity = cosine_similarity(test_anchor, test_pos)
print("Positive similarity:", positive_similarity.numpy())

negative_similarity = cosine_similarity(test_anchor, test_neg)
print("Negative similarity", negative_similarity.numpy())
# Out:
# Positive similarity: 0.9239287
# Negative similarity 0.9251517
